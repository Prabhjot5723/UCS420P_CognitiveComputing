# %% [markdown]
# # Assignment-3: Pandas
# ## Questions 4 and 5
#
# UCS420 Cognitive Computing

# %% [markdown]
# ## Q4. Read a CSV file and display its first five rows
#
# Download the Iris dataset from Kaggle as mentioned in the assignment and place `Iris.csv` in the same folder as this notebook.

# %%
import pandas as pd

df = pd.read_csv("Iris.csv")

print("Q4. First five rows:")
display(df.head())

# %% [markdown]
# ## Q5. Delete row 4 and column 3, then display the result

# %%
# Delete row with index 4
df = df.drop(index=4)

# Delete column with index 3
df = df.drop(df.columns[3], axis=1)

print("Q5. After deleting row 4 and column 3:")
display(df)
